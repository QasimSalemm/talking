# %% [markdown]
# # Real-ESRGAN Video Enhancement (No Scaling)
# This notebook allows you to use Real-ESRGAN in Google Colab to enhance the quality of your videos while maintaining the exact same resolution (scaling factor of 1).
#
# This is particularly useful when you want to restore or denoise a video without arbitrarily increasing spatial dimensions and file sizes.

# %%
# 1. Clone the Real-ESRGAN repository
# !git clone https://github.com/xinntao/Real-ESRGAN.git
# %cd Real-ESRGAN

# 2. Install dependencies
# !pip install basicsr
# !pip install facexlib
# !pip install gfpgan
# !pip install -r requirements.txt
# !python setup.py develop

# 3. Fix the basicsr bug caused by newer torchvision versions
# !sed -i 's/from torchvision.transforms.functional_tensor import rgb_to_grayscale/from torchvision.transforms.functional import rgb_to_grayscale/' /usr/local/lib/python3.*/dist-packages/basicsr/data/degradations.py

# 4. Install ffmpeg for video handling
# !apt-get install -y ffmpeg
# !pip install ffmpeg-python
# Out:
# Cloning into 'Real-ESRGAN'...
# remote: Enumerating objects: 759, done.
# remote: Total 759 (delta 0), reused 0 (delta 0), pack-reused 759 (from 1)
# Receiving objects: 100% (759/759), 5.39 MiB | 10.44 MiB/s, done.
# Resolving deltas: 100% (408/408), done.
# /content/Real-ESRGAN
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.5/172.5 kB 7.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 333.1/333.1 kB 26.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 115.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 30.4 MB/s eta 0:00:00
# ...
#   Created wheel for basicsr: filename=basicsr-1.4.2-py3-none-any.whl size=214819 sha256=f7f88e09f261566c59aece7016654fbfe4307c6296c19fdb3dcea516c9fb73eb
#   Stored in directory: /root/.cache/pip/wheels/9a/e3/e4/58f29bfabb622dd40b6d9839318ce5bf092062b81ca3aa19ea
# ...

# %%
import glob
video_files = glob.glob('upload/*')
if len(video_files) == 0:
    print('Error: No video found in "upload" folder. Please upload a video first.')
else:
    input_video = video_files[0] # Get the uploaded video path
    print(f'Processing video: {input_video}')
    # !python inference_realesrgan_video.py -i "{input_video}" -o results -n realesr-general-x4v3 -s 1 -t 512 --face_enhance
# Out:
# Processing video: upload/res_20260401-044602-369.mp4
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# inference:   0% 0/1162 [00:00<?, ?frame/s]	Tile 1/1
# inference:   0% 1/1162 [00:00<17:07,  1.13frame/s]	Tile 1/1
# inference:   0% 2/1162 [00:01<11:29,  1.68frame/s]	Tile 1/1
# inference:   0% 3/1162 [00:01<10:01,  1.93frame/s]	Tile 1/1
# inference:   0% 4/1162 [00:02<09:22,  2.06frame/s]	Tile 1/1
# inference:   0% 5/1162 [00:02<08:55,  2.16frame/s]	Tile 1/1
# inference:   1% 6/1162 [00:02<08:41,  2.22frame/s]	Tile 1/1
# ...

# %%
# Download the resulting enhanced video
import os
import glob
from google.colab import files

for f in glob.glob(os.path.join(result_folder, '*.*')):
    print(f'Downloading {f} - this might take a minute')
    files.download(f)
